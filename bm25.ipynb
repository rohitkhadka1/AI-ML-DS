# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitkhadka1/AI-ML-DS/blob/main/bm25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bm25s

# %%
corpus = [
    "a cat is a feline and likes to purr",
    "a dog is the human's best friend and loves to play",
    "a bird is a beautiful animal that can fly",
    "a fish is a creature that lives in water and swims",
]

# %%
# Tokenize the corpus
corpus_tokens = bm25s.tokenize(corpus)

# Create the BM25 model and index the corpus
retriever = bm25s.BM25()
retriever.index(corpus_tokens)
# Out:
# DEBUG:bm25s:Building index from tokens
# ...
# BM25S Compute Scores:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Query the corpus and get the top-k results
query = "does the fish purr like a cat ?"
results, scores = retriever.retrieve(bm25s.tokenize(query), k=2)
# Out:
# ...
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Let us see what we got
for i, (doc, score) in enumerate(zip(results[0], scores[0])):
    print(f"Rank {i+1} (score: {score:.2f}): {doc}")
# Out:
# Rank 1 (score: 1.06): a cat is a feline and likes to purr
# Rank 2 (score: 0.48): a fish is a creature that lives in water and swims
